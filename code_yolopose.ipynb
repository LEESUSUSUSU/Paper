# %%
import zipfile
import os

def unzip(file_path, extract_dir):
  with zipfile.ZipFile(file_path, 'r') as zip_ref:
    for zipinfo in zip_ref.infolist():
        filename = zipinfo.filename
        # Replace problematic characters in the filename
        sanitized_filename = filename.encode('cp437', 'surrogateescape').decode('utf-8', 'replace')
        zipinfo.filename = sanitized_filename
        zip_ref.extract(zipinfo, extract_dir)

# 사용 예시
file_path = '/content/drive/MyDrive/zerobase/논문반/archive.zip'  # 압축 파일 경로
extract_dir = '/content/drive/MyDrive/zerobase/논문반'  # 압축을 풀 디렉토리 경로

unzip(file_path, extract_dir)

# %%
import cv2
import os

def video_to_images(video_path, output_dir):
  """
  비디오를 이미지 프레임으로 변환하여 저장하는 함수

  Args:
    video_path: 비디오 파일 경로
    output_dir: 이미지를 저장할 디렉토리 경로
  """
  # 비디오 캡처 객체 생성
  cap = cv2.VideoCapture(video_path)

  # 프레임 번호 초기화
  frame_count = 0

  # 이미지 저장 디렉토리 생성
  os.makedirs(output_dir, exist_ok=True)

  # 비디오 프레임 추출 및 저장
  while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
      break

    # 이미지 파일 이름 생성
    image_file = os.path.join(output_dir, f"frame_{frame_count:04d}.jpg")

    # 이미지 저장
    cv2.imwrite(image_file, frame)

    frame_count += 1

  # 자원 해제
  cap.release()

# 사용 예시
video_dir = '/content/drive/MyDrive/zerobase/논문반/RWF-2000/train/Fight'  # 원본 영상이 담긴 폴더 경로
output_dir = '/content/drive/MyDrive/zerobase/논문반/RWF-2000/train_images'  # 이미지를 저장할 디렉토리 경로

# 폴더 내 모든 비디오 파일에 대해 이미지 변환 수행
for filename in os.listdir(video_dir):
  if filename.endswith('.avi'):  # .mp4 확장자를 가진 파일만 처리
    video_path = os.path.join(video_dir, filename)
    video_name = os.path.splitext(filename)[0]  # 비디오 파일 이름 (확장자 제외)
    image_output_dir = os.path.join(output_dir, video_name)  # 각 비디오별 이미지 저장 디렉토리
    video_to_images(video_path, image_output_dir)

# %%
import os
import cv2
import torch
import pandas as pd
import numpy as np
from ultralytics import YOLO

class GetKeypoint:
    NOSE = 0
    LEFT_EYE = 1
    RIGHT_EYE = 2
    LEFT_EAR = 3
    RIGHT_EAR = 4
    LEFT_SHOULDER = 5
    RIGHT_SHOULDER = 6
    LEFT_ELBOW = 7
    RIGHT_ELBOW = 8
    LEFT_WRIST = 9
    RIGHT_WRIST = 10
    LEFT_HIP = 11
    RIGHT_HIP = 12
    LEFT_KNEE = 13
    RIGHT_KNEE = 14
    LEFT_ANKLE = 15
    RIGHT_ANKLE = 16

get_keypoint = GetKeypoint()

def classify_pose(keypoints):
    # 키포인트가 비어있거나 None인 경우 처리
    if keypoints is None or len(keypoints) == 0:
        print("No keypoints detected.")
        return 'unknown'  # 기본 행동 반환

    # 첫 번째 사람의 키포인트를 가져옴
    keypoints_data = keypoints.data[0]  # 첫 번째 사람의 키포인트 데이터
    if keypoints_data.shape[0] < 17:  # 17개의 키포인트 필요
        print("Not enough keypoints provided.")
        return 'unknown'  # 또는 다른 기본 행동 반환

    # 각 신체 부위의 y 좌표 설정
    nose_y = keypoints_data[GetKeypoint.NOSE, 1].item()
    left_shoulder_y = keypoints_data[GetKeypoint.LEFT_SHOULDER, 1].item()
    right_shoulder_y = keypoints_data[GetKeypoint.RIGHT_SHOULDER, 1].item()
    left_hip_y = keypoints_data[GetKeypoint.LEFT_HIP, 1].item()
    right_hip_y = keypoints_data[GetKeypoint.RIGHT_HIP, 1].item()
    left_knee_y = keypoints_data[GetKeypoint.LEFT_KNEE, 1].item()
    right_knee_y = keypoints_data[GetKeypoint.RIGHT_KNEE, 1].item()
    left_elbow_y = keypoints_data[GetKeypoint.LEFT_ELBOW, 1].item()
    right_elbow_y = keypoints_data[GetKeypoint.RIGHT_ELBOW, 1].item()
    left_wrist_y = keypoints_data[GetKeypoint.LEFT_WRIST, 1].item()
    right_wrist_y = keypoints_data[GetKeypoint.RIGHT_WRIST, 1].item()
    left_ankle_y = keypoints_data[GetKeypoint.LEFT_ANKLE, 1].item()
    right_ankle_y = keypoints_data[GetKeypoint.RIGHT_ANKLE, 1].item()

    shoulder_diff = abs(left_shoulder_y - right_shoulder_y)
    hip_diff = abs(left_hip_y - right_hip_y)
    shoulder_hip_diff = min(abs(left_shoulder_y - left_hip_y), abs(right_shoulder_y - right_hip_y))
    hip_knee_diff = min(abs(left_hip_y - left_knee_y), abs(right_hip_y - right_knee_y))
    elbow_wrist_diff = min(abs(left_elbow_y - left_wrist_y), abs(right_elbow_y - right_wrist_y))
    knee_ankle_diff = min(abs(left_knee_y - left_ankle_y), abs(right_knee_y - right_ankle_y))
    elbow_diff = abs(left_elbow_y - right_elbow_y)
    foot_diff = abs(left_ankle_y - right_ankle_y)
    foot_y = min(left_ankle_y, right_ankle_y)

    if shoulder_diff < 20 and hip_diff < 20:
        return 'falling'
    elif shoulder_diff < 20 and hip_diff < 20 and shoulder_hip_diff > 50 and hip_knee_diff < 30:
        return 'attack'
    elif nose_y < min(left_shoulder_y, right_shoulder_y) and shoulder_hip_diff > 50:
        return 'defense'
    elif shoulder_hip_diff > 50 and hip_knee_diff < 30 and knee_ankle_diff > 50:
        return 'aggressive'
    elif elbow_wrist_diff < 20 and min(left_wrist_y, right_wrist_y) < nose_y + 20:
        return 'punch'
    elif elbow_wrist_diff < 20 and max(left_wrist_y, right_wrist_y) > max(left_shoulder_y, right_shoulder_y):
        return 'push'
    elif abs(left_wrist_y - right_wrist_y) < 20 and min(left_wrist_y, right_wrist_y) < nose_y + 20 and min(left_wrist_y, right_wrist_y) > nose_y - 20:
        return 'grab_collar'
    elif knee_ankle_diff > 50 and foot_y < hip_diff:
        return 'kicking'
    elif elbow_diff < 20 and min(left_elbow_y, right_elbow_y) < shoulder_diff:
        return 'elbow_strike'
    elif shoulder_hip_diff > 50 and elbow_wrist_diff < 20 and max(left_wrist_y, right_wrist_y) > max(left_shoulder_y, right_shoulder_y):
        return 'shoving'
    elif abs(left_wrist_y - right_wrist_y) < 20 and min(left_wrist_y, right_wrist_y) < nose_y + 10 and min(left_wrist_y, right_wrist_y) > nose_y - 10:
        return 'choking'
    elif foot_diff > 50 and foot_y > min(left_ankle_y, right_ankle_y):
        return 'stomping'
    elif shoulder_hip_diff < 50 and hip_knee_diff < 50 and min(left_knee_y, right_knee_y) < nose_y:
        return 'crouching'
    else:
        return 'neutral'

def vis_frame(orig_img, boxes, keypoints, labels):
    vis_img = orig_img.copy()

    # boxes가 비어있거나 길이가 0일 경우 처리
    if boxes is None or len(boxes) == 0:
        print("No boxes detected.")
        return vis_img

    for i in range(len(boxes)):
        box = boxes[i].xyxy  # 각 박스의 좌표 가져오기
        if len(box) == 0:
            continue  # 박스가 없다면 건너뜀
        x1, y1, x2, y2 = box[0]  # 첫 번째 박스 좌표 가져오기
        cv2.rectangle(vis_img, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)

        # 키포인트 시각화
        if keypoints is not None and len(keypoints) > i:
            keypoints_data = keypoints[i].data  # 각 사람의 키포인트 데이터
            for j in range(keypoints_data.shape[0]):  # 각 키포인트 수 만큼 반복
                if keypoints_data[j].shape[0] == 3:  # (x, y, confidence) 확인
                    x, y, conf = keypoints_data[j].cpu().numpy()  # x, y 좌표와 신뢰도 가져오기
                    if conf > 0.5:  # 신뢰도가 0.5 이상인 경우에만 표시
                        cv2.circle(vis_img, (int(x), int(y)), 5, (0, 255, 0), -1)
            cv2.putText(vis_img, labels[i], (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
    return vis_img



def main():
    # YOLO Pose 모델 로드
    yolo_pose_model = YOLO('yolov8n-pose.pt')  # 다운로드한 모델 경로

    image_files = []
    image_directory = '/content/drive/MyDrive/zerobase/논문반/RWF-2000/train_images'

    for root, dirs, files in os.walk(image_directory):
        for file in files:
            if file.lower().endswith(('.png', '.jpg', '.jpeg')):
                image_files.append(os.path.join(root, file))

    image_files = sorted(image_files)
    output_directory = '/content/drive/MyDrive/zerobase/results/'
    csv_file_path = '/content/drive/MyDrive/zerobase/train_pose2_keypoint.csv'
    last_processed_file_path = '/content/drive/MyDrive/zerobase/last_processed_image.txt'

    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    # 마지막으로 처리한 이미지 읽기
    last_processed_image = None
    if os.path.exists(last_processed_file_path):
        with open(last_processed_file_path, 'r') as f:
            last_processed_image = f.read().strip()

    all_keypoints = []

    # 모든 이미지 파일 처리
    for idx, image_file in enumerate(image_files):
        # 마지막 처리한 이미지부터 이어서 처리
        if last_processed_image is not None and image_file <= last_processed_image:
            print(f'이미지 이미 처리됨, 건너뜁니다: {image_file}')
            continue

        input_image = cv2.imread(image_file)
        if input_image is None:
            print(f'오류: 이미지 {image_file}를 찾을 수 없거나 읽을 수 없습니다.')
            continue

        try:
            # YOLO Pose 모델 실행
            results = yolo_pose_model.predict(input_image, save=False)

            keypoints = results[0].keypoints  # YOLOv8의 Keypoints 객체
            boxes = results[0].boxes  # YOLOv8의 Boxes 객체
            labels = []

            if keypoints is not None:
                for i in range(len(keypoints)):
                    keypoints_data = keypoints[i].data  # 첫 번째 사람의 키포인트 데이터
                    label = classify_pose(keypoints_data)  # 포즈 분류
                    labels.append(label)

            # 결과 시각화 및 저장
            result_img = vis_frame(input_image, boxes, keypoints, labels)
            output_path = os.path.join(output_directory, f'result_{os.path.basename(image_file)}')
            cv2.imwrite(output_path, result_img)
            print(f'결과가 저장되었습니다: {output_path}')

            # 키포인트 저장 로직
            keypoints_data = [image_file] + labels + [k for k in keypoints]  # 각 키포인트 데이터 추가
            all_keypoints.append(keypoints_data)

            # 마지막으로 처리된 이미지 기록
            with open(last_processed_file_path, 'w') as f:
                f.write(image_file)

        except Exception as e:
            print(f'처리 중 오류 발생: {e}')

    # 최종 CSV 파일 저장
    df = pd.DataFrame(all_keypoints)
    df.to_csv(csv_file_path, index=False)
    print(f'키포인트가 {csv_file_path}에 저장되었습니다.')

if __name__ == '__main__':
    main()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n-pose.pt to 'yolov8n-pose.pt'...
# 100%|██████████| 6.52M/6.52M [00:00<00:00, 78.5MB/s]
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0120.jpg
#
# 0: 384x640 1 person, 284.3ms
# Speed: 2.9ms preprocess, 284.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0121.jpg
#
# 0: 384x640 1 person, 181.5ms
# Speed: 4.1ms preprocess, 181.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0122.jpg
#
# 0: 384x640 1 person, 171.2ms
# Speed: 5.9ms preprocess, 171.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0123.jpg
#
# 0: 384x640 1 person, 177.1ms
# Speed: 5.4ms preprocess, 177.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0124.jpg
#
# 0: 384x640 1 person, 170.3ms
# Speed: 3.2ms preprocess, 170.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0125.jpg
#
# 0: 384x640 1 person, 213.8ms
# Speed: 4.0ms preprocess, 213.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0126.jpg
#
# 0: 384x640 1 person, 166.1ms
# Speed: 4.1ms preprocess, 166.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0127.jpg
#
# 0: 384x640 1 person, 170.0ms
# Speed: 4.3ms preprocess, 170.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0128.jpg
#
# 0: 384x640 1 person, 171.3ms
# Speed: 2.9ms preprocess, 171.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0129.jpg
#
# 0: 384x640 1 person, 176.9ms
# Speed: 4.5ms preprocess, 176.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0130.jpg
#
# 0: 384x640 1 person, 177.1ms
# Speed: 4.2ms preprocess, 177.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0131.jpg
#
# 0: 384x640 1 person, 176.1ms
# Speed: 5.3ms preprocess, 176.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0132.jpg
#
# 0: 384x640 1 person, 170.5ms
# Speed: 4.1ms preprocess, 170.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0133.jpg
#
# 0: 384x640 1 person, 176.6ms
# Speed: 5.4ms preprocess, 176.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0134.jpg
#
# 0: 384x640 1 person, 159.4ms
# Speed: 8.8ms preprocess, 159.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0135.jpg
#
# 0: 384x640 1 person, 167.8ms
# Speed: 4.0ms preprocess, 167.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0136.jpg
#
# 0: 384x640 1 person, 176.4ms
# Speed: 3.2ms preprocess, 176.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0137.jpg
#
# 0: 384x640 1 person, 244.6ms
# Speed: 3.5ms preprocess, 244.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0138.jpg
#
# 0: 384x640 1 person, 295.2ms
# Speed: 7.7ms preprocess, 295.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0139.jpg
#
# 0: 384x640 1 person, 293.0ms
# Speed: 2.8ms preprocess, 293.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0140.jpg
#
# 0: 384x640 1 person, 277.2ms
# Speed: 2.9ms preprocess, 277.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0141.jpg
#
# 0: 384x640 1 person, 262.6ms
# Speed: 3.3ms preprocess, 262.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0142.jpg
#
# 0: 384x640 1 person, 373.7ms
# Speed: 6.1ms preprocess, 373.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0143.jpg
#
# 0: 384x640 1 person, 297.2ms
# Speed: 2.7ms preprocess, 297.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0144.jpg
#
# 0: 384x640 1 person, 306.7ms
# Speed: 2.9ms preprocess, 306.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0145.jpg
#
# 0: 384x640 1 person, 336.9ms
# Speed: 6.1ms preprocess, 336.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0146.jpg
#
# 0: 384x640 1 person, 292.6ms
# Speed: 2.9ms preprocess, 292.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0147.jpg
#
# 0: 384x640 1 person, 277.1ms
# Speed: 4.5ms preprocess, 277.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0148.jpg
#
# 0: 384x640 1 person, 295.6ms
# Speed: 2.9ms preprocess, 295.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0149.jpg
#
# 0: 480x640 (no detections), 322.4ms
# Speed: 3.5ms preprocess, 322.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Not enough keypoints provided.
# No boxes detected.
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0000.jpg
#
# 0: 480x640 1 person, 291.3ms
# Speed: 7.3ms preprocess, 291.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0001.jpg
#
# 0: 480x640 1 person, 203.3ms
# Speed: 3.8ms preprocess, 203.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0002.jpg
#
# 0: 480x640 1 person, 214.0ms
# Speed: 3.9ms preprocess, 214.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0003.jpg
#
# 0: 480x640 1 person, 215.0ms
# Speed: 6.2ms preprocess, 215.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0004.jpg
#
# 0: 480x640 1 person, 228.9ms
# Speed: 5.1ms preprocess, 228.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0005.jpg
#
# 0: 480x640 1 person, 209.8ms
# Speed: 6.1ms preprocess, 209.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0006.jpg
#
# 0: 480x640 1 person, 196.0ms
# Speed: 3.8ms preprocess, 196.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0007.jpg
#
# 0: 480x640 1 person, 200.8ms
# Speed: 4.2ms preprocess, 200.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0008.jpg
#
# 0: 480x640 1 person, 215.2ms
# Speed: 5.3ms preprocess, 215.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0009.jpg
#
# 0: 480x640 1 person, 221.0ms
# Speed: 7.6ms preprocess, 221.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0010.jpg
#
# 0: 480x640 1 person, 202.4ms
# Speed: 4.6ms preprocess, 202.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0011.jpg
#
# 0: 480x640 1 person, 213.0ms
# Speed: 3.5ms preprocess, 213.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0012.jpg
#
# 0: 480x640 1 person, 200.4ms
# Speed: 3.6ms preprocess, 200.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0013.jpg
#
# 0: 480x640 1 person, 230.2ms
# Speed: 5.6ms preprocess, 230.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0014.jpg
#
# 0: 480x640 1 person, 203.0ms
# Speed: 7.3ms preprocess, 203.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0015.jpg
#
# 0: 480x640 1 person, 226.5ms
# Speed: 4.1ms preprocess, 226.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0016.jpg
#
# 0: 480x640 1 person, 205.2ms
# Speed: 4.1ms preprocess, 205.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0017.jpg
#
# 0: 480x640 1 person, 207.4ms
# Speed: 3.6ms preprocess, 207.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0018.jpg
#
# 0: 480x640 1 person, 209.5ms
# Speed: 4.8ms preprocess, 209.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0019.jpg
#
# 0: 480x640 1 person, 200.8ms
# Speed: 5.1ms preprocess, 200.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0020.jpg
#
# 0: 480x640 (no detections), 203.9ms
# Speed: 4.9ms preprocess, 203.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Not enough keypoints provided.
# No boxes detected.
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0021.jpg
#
# 0: 480x640 1 person, 204.3ms
# Speed: 6.4ms preprocess, 204.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0022.jpg
#
# 0: 480x640 2 persons, 321.7ms
# Speed: 5.8ms preprocess, 321.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0023.jpg
#
# 0: 480x640 1 person, 313.1ms
# Speed: 3.6ms preprocess, 313.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0024.jpg
#
# 0: 480x640 1 person, 321.4ms
# Speed: 4.6ms preprocess, 321.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0025.jpg
#
# 0: 480x640 (no detections), 314.3ms
# Speed: 4.4ms preprocess, 314.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Not enough keypoints provided.
# No boxes detected.
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0026.jpg
#
# 0: 480x640 (no detections), 331.0ms
# Speed: 5.9ms preprocess, 331.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Not enough keypoints provided.
# No boxes detected.
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0027.jpg
#
# 0: 480x640 (no detections), 341.3ms
# Speed: 3.4ms preprocess, 341.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Not enough keypoints provided.
# No boxes detected.
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0028.jpg
#
# 0: 480x640 (no detections), 321.7ms
# Speed: 4.0ms preprocess, 321.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Not enough keypoints provided.
# No boxes detected.
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0029.jpg
#
# 0: 480x640 (no detections), 195.8ms
# Speed: 4.0ms preprocess, 195.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Not enough keypoints provided.
# No boxes detected.
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0030.jpg
#
# 0: 480x640 1 person, 225.3ms
# Speed: 3.9ms preprocess, 225.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0031.jpg
#
# 0: 480x640 1 person, 204.4ms
# Speed: 5.4ms preprocess, 204.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0032.jpg
#
# 0: 480x640 (no detections), 234.5ms
# Speed: 5.0ms preprocess, 234.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Not enough keypoints provided.
# No boxes detected.
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0033.jpg
#
# 0: 480x640 1 person, 194.8ms
# Speed: 3.2ms preprocess, 194.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0034.jpg
#
# 0: 480x640 1 person, 211.0ms
# Speed: 6.4ms preprocess, 211.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0035.jpg
#
# 0: 480x640 1 person, 197.5ms
# Speed: 4.2ms preprocess, 197.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0036.jpg
#
# 0: 480x640 2 persons, 207.7ms
# Speed: 7.4ms preprocess, 207.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0037.jpg
#
# 0: 480x640 1 person, 196.5ms
# Speed: 3.7ms preprocess, 196.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0038.jpg
#
# 0: 480x640 1 person, 203.8ms
# Speed: 5.1ms preprocess, 203.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0039.jpg
#
# 0: 480x640 1 person, 195.3ms
# Speed: 6.4ms preprocess, 195.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0040.jpg
#
# 0: 480x640 1 person, 207.6ms
# Speed: 3.7ms preprocess, 207.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0041.jpg
#
# 0: 480x640 1 person, 203.7ms
# Speed: 4.4ms preprocess, 203.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0042.jpg
#
# 0: 480x640 2 persons, 206.7ms
# Speed: 3.7ms preprocess, 206.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0043.jpg
#
# 0: 480x640 2 persons, 216.0ms
# Speed: 5.6ms preprocess, 216.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0044.jpg
#
# 0: 480x640 2 persons, 208.8ms
# Speed: 4.4ms preprocess, 208.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0045.jpg
#
# 0: 480x640 2 persons, 211.1ms
# Speed: 3.7ms preprocess, 211.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0046.jpg
#
# 0: 480x640 2 persons, 216.0ms
# Speed: 5.1ms preprocess, 216.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0047.jpg
#
# 0: 480x640 2 persons, 230.0ms
# Speed: 4.1ms preprocess, 230.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0048.jpg
#
# 0: 480x640 2 persons, 198.5ms
# Speed: 6.6ms preprocess, 198.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0049.jpg
#
# 0: 480x640 2 persons, 272.3ms
# Speed: 6.2ms preprocess, 272.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0050.jpg
#
# 0: 480x640 2 persons, 307.8ms
# Speed: 3.8ms preprocess, 307.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0051.jpg
#
# 0: 480x640 2 persons, 349.8ms
# Speed: 6.6ms preprocess, 349.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0052.jpg
#
# 0: 480x640 3 persons, 324.0ms
# Speed: 3.6ms preprocess, 324.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0053.jpg
#
# 0: 480x640 2 persons, 338.7ms
# Speed: 3.8ms preprocess, 338.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0054.jpg
#
# 0: 480x640 2 persons, 321.6ms
# Speed: 3.5ms preprocess, 321.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0055.jpg
#
# 0: 480x640 2 persons, 399.2ms
# Speed: 4.1ms preprocess, 399.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0056.jpg
#
# 0: 480x640 2 persons, 206.2ms
# Speed: 4.2ms preprocess, 206.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0057.jpg
#
# 0: 480x640 2 persons, 206.3ms
# Speed: 4.8ms preprocess, 206.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0058.jpg
#
# 0: 480x640 2 persons, 209.1ms
# Speed: 5.2ms preprocess, 209.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0059.jpg
#
# 0: 480x640 2 persons, 225.7ms
# Speed: 4.2ms preprocess, 225.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0060.jpg
#
# 0: 480x640 2 persons, 206.9ms
# Speed: 3.5ms preprocess, 206.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0061.jpg
#
# 0: 480x640 2 persons, 235.8ms
# Speed: 5.6ms preprocess, 235.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0062.jpg
#
# 0: 480x640 2 persons, 208.1ms
# Speed: 3.5ms preprocess, 208.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0063.jpg
#
# 0: 480x640 2 persons, 198.3ms
# Speed: 6.4ms preprocess, 198.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0064.jpg
#
# 0: 480x640 2 persons, 208.5ms
# Speed: 3.7ms preprocess, 208.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0065.jpg
#
# 0: 480x640 1 person, 195.3ms
# Speed: 4.0ms preprocess, 195.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0066.jpg
#
# 0: 480x640 2 persons, 213.8ms
# Speed: 4.7ms preprocess, 213.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0067.jpg
#
# 0: 480x640 2 persons, 205.1ms
# Speed: 4.3ms preprocess, 205.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0068.jpg
#
# 0: 480x640 2 persons, 228.6ms
# Speed: 3.4ms preprocess, 228.6ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0069.jpg
#
# 0: 480x640 2 persons, 201.3ms
# Speed: 4.8ms preprocess, 201.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0070.jpg
#
# 0: 480x640 1 person, 233.0ms
# Speed: 4.0ms preprocess, 233.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0071.jpg
#
# 0: 480x640 2 persons, 200.1ms
# Speed: 4.0ms preprocess, 200.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0072.jpg
#
# 0: 480x640 1 person, 200.6ms
# Speed: 3.8ms preprocess, 200.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0073.jpg
#
# 0: 480x640 1 person, 209.3ms
# Speed: 4.7ms preprocess, 209.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0074.jpg
#
# 0: 480x640 1 person, 235.4ms
# Speed: 4.3ms preprocess, 235.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0075.jpg
#
# 0: 480x640 1 person, 199.2ms
# Speed: 4.0ms preprocess, 199.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0076.jpg
#
# 0: 480x640 1 person, 210.4ms
# Speed: 3.4ms preprocess, 210.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0077.jpg
#
# 0: 480x640 1 person, 313.7ms
# Speed: 3.7ms preprocess, 313.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0078.jpg
#
# 0: 480x640 1 person, 342.1ms
# Speed: 5.4ms preprocess, 342.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0079.jpg
#
# 0: 480x640 1 person, 309.8ms
# Speed: 3.6ms preprocess, 309.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0080.jpg
#
# 0: 480x640 2 persons, 346.3ms
# Speed: 7.7ms preprocess, 346.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0081.jpg
#
# 0: 480x640 1 person, 320.2ms
# Speed: 3.6ms preprocess, 320.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0082.jpg
#
# 0: 480x640 2 persons, 341.8ms
# Speed: 3.7ms preprocess, 341.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0083.jpg
#
# 0: 480x640 2 persons, 301.2ms
# Speed: 4.6ms preprocess, 301.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0084.jpg
#
# 0: 480x640 2 persons, 210.1ms
# Speed: 3.9ms preprocess, 210.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0085.jpg
#
# 0: 480x640 2 persons, 218.8ms
# Speed: 3.5ms preprocess, 218.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0086.jpg
#
# 0: 480x640 1 person, 205.8ms
# Speed: 3.7ms preprocess, 205.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0087.jpg
#
# 0: 480x640 2 persons, 209.7ms
# Speed: 5.5ms preprocess, 209.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0088.jpg
#
# 0: 480x640 1 person, 215.4ms
# Speed: 7.7ms preprocess, 215.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0089.jpg
#
# 0: 480x640 1 person, 213.0ms
# Speed: 3.9ms preprocess, 213.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0090.jpg
#
# 0: 480x640 1 person, 218.7ms
# Speed: 3.5ms preprocess, 218.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0091.jpg
#
# 0: 480x640 1 person, 207.9ms
# Speed: 4.2ms preprocess, 207.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0092.jpg
#
# 0: 480x640 1 person, 224.8ms
# Speed: 4.4ms preprocess, 224.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0093.jpg
#
# 0: 480x640 1 person, 203.6ms
# Speed: 3.8ms preprocess, 203.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0094.jpg
#
# 0: 480x640 1 person, 217.8ms
# Speed: 4.1ms preprocess, 217.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0095.jpg
#
# 0: 480x640 2 persons, 196.9ms
# Speed: 3.4ms preprocess, 196.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0096.jpg
#
# 0: 480x640 2 persons, 195.9ms
# Speed: 5.7ms preprocess, 195.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0097.jpg
#
# 0: 480x640 2 persons, 195.9ms
# Speed: 3.5ms preprocess, 195.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0098.jpg
#
# 0: 480x640 1 person, 213.8ms
# Speed: 5.8ms preprocess, 213.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0099.jpg
#
# 0: 480x640 1 person, 212.7ms
# Speed: 4.5ms preprocess, 212.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0100.jpg
#
# 0: 480x640 1 person, 227.8ms
# Speed: 4.3ms preprocess, 227.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0101.jpg
#
# 0: 480x640 1 person, 210.4ms
# Speed: 5.0ms preprocess, 210.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0102.jpg
#
# 0: 480x640 2 persons, 211.8ms
# Speed: 4.2ms preprocess, 211.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0103.jpg
#
# 0: 480x640 2 persons, 198.6ms
# Speed: 6.3ms preprocess, 198.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0104.jpg
#
# 0: 480x640 2 persons, 198.0ms
# Speed: 4.8ms preprocess, 198.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0105.jpg
#
# 0: 480x640 2 persons, 296.6ms
# Speed: 3.4ms preprocess, 296.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0106.jpg
#
# 0: 480x640 2 persons, 336.4ms
# Speed: 3.6ms preprocess, 336.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0107.jpg
#
# 0: 480x640 2 persons, 302.2ms
# Speed: 5.4ms preprocess, 302.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0108.jpg
#
# 0: 480x640 2 persons, 326.2ms
# Speed: 3.4ms preprocess, 326.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0109.jpg
#
# 0: 480x640 2 persons, 330.1ms
# Speed: 3.5ms preprocess, 330.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0110.jpg
#
# 0: 480x640 2 persons, 348.2ms
# Speed: 6.5ms preprocess, 348.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0111.jpg
#
# 0: 480x640 1 person, 298.0ms
# Speed: 3.5ms preprocess, 298.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0112.jpg
#
# 0: 480x640 1 person, 206.1ms
# Speed: 4.0ms preprocess, 206.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0113.jpg
#
# 0: 480x640 1 person, 225.0ms
# Speed: 3.3ms preprocess, 225.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0114.jpg
#
# 0: 480x640 1 person, 200.4ms
# Speed: 4.3ms preprocess, 200.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0115.jpg
#
# 0: 480x640 1 person, 218.8ms
# Speed: 3.6ms preprocess, 218.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0116.jpg
#
# 0: 480x640 1 person, 210.7ms
# Speed: 4.9ms preprocess, 210.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0117.jpg
#
# 0: 480x640 1 person, 231.4ms
# Speed: 4.3ms preprocess, 231.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0118.jpg
#
# 0: 480x640 2 persons, 199.0ms
# Speed: 6.2ms preprocess, 199.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0119.jpg
#
# 0: 480x640 2 persons, 211.8ms
# Speed: 4.7ms preprocess, 211.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0120.jpg
#
# 0: 480x640 1 person, 196.4ms
# Speed: 6.2ms preprocess, 196.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0121.jpg
#
# 0: 480x640 1 person, 218.7ms
# Speed: 5.5ms preprocess, 218.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0122.jpg
#
# 0: 480x640 1 person, 210.0ms
# Speed: 3.4ms preprocess, 210.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0123.jpg
#
# 0: 480x640 1 person, 208.7ms
# Speed: 3.1ms preprocess, 208.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0124.jpg
#
# 0: 480x640 1 person, 208.4ms
# Speed: 3.7ms preprocess, 208.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0125.jpg
#
# 0: 480x640 1 person, 205.0ms
# Speed: 3.8ms preprocess, 205.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0126.jpg
#
# 0: 480x640 1 person, 204.0ms
# Speed: 3.5ms preprocess, 204.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0127.jpg
#
# 0: 480x640 1 person, 205.8ms
# Speed: 3.6ms preprocess, 205.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0128.jpg
#
# 0: 480x640 2 persons, 228.2ms
# Speed: 5.2ms preprocess, 228.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0129.jpg
#
# 0: 480x640 1 person, 200.1ms
# Speed: 3.4ms preprocess, 200.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0130.jpg
#
# 0: 480x640 1 person, 222.8ms
# Speed: 3.8ms preprocess, 222.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0131.jpg
#
# 0: 480x640 1 person, 205.6ms
# Speed: 6.3ms preprocess, 205.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0132.jpg
#
# 0: 480x640 1 person, 245.6ms
# Speed: 3.5ms preprocess, 245.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0133.jpg
#
# 0: 480x640 1 person, 310.5ms
# Speed: 7.7ms preprocess, 310.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0134.jpg
#
# 0: 480x640 1 person, 340.0ms
# Speed: 3.7ms preprocess, 340.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0135.jpg
#
# 0: 480x640 1 person, 309.9ms
# Speed: 3.6ms preprocess, 309.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0136.jpg
#
# 0: 480x640 1 person, 297.3ms
# Speed: 3.7ms preprocess, 297.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0137.jpg
#
# 0: 480x640 1 person, 328.6ms
# Speed: 3.8ms preprocess, 328.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0138.jpg
#
# 0: 480x640 1 person, 328.0ms
# Speed: 6.8ms preprocess, 328.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0139.jpg
#
# 0: 480x640 1 person, 270.1ms
# Speed: 3.4ms preprocess, 270.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0140.jpg
#
# 0: 480x640 2 persons, 196.8ms
# Speed: 3.7ms preprocess, 196.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0141.jpg
#
# 0: 480x640 2 persons, 212.9ms
# Speed: 4.1ms preprocess, 212.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0142.jpg
#
# 0: 480x640 1 person, 194.0ms
# Speed: 4.2ms preprocess, 194.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0143.jpg
#
# 0: 480x640 1 person, 201.5ms
# Speed: 7.4ms preprocess, 201.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0144.jpg
#
# 0: 480x640 1 person, 196.3ms
# Speed: 3.5ms preprocess, 196.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0145.jpg
#
# 0: 480x640 1 person, 195.3ms
# Speed: 3.5ms preprocess, 195.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0146.jpg
#
# 0: 480x640 1 person, 213.4ms
# Speed: 4.6ms preprocess, 213.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0147.jpg
#
# 0: 480x640 1 person, 200.5ms
# Speed: 5.4ms preprocess, 200.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0148.jpg
#
# 0: 480x640 1 person, 214.2ms
# Speed: 3.9ms preprocess, 214.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0149.jpg
#
# 0: 384x640 4 persons, 164.8ms
# Speed: 3.5ms preprocess, 164.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0000.jpg
#
# 0: 384x640 4 persons, 176.7ms
# Speed: 3.3ms preprocess, 176.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0001.jpg
#
# 0: 384x640 5 persons, 170.3ms
# Speed: 2.3ms preprocess, 170.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0002.jpg
#
# 0: 384x640 4 persons, 169.5ms
# Speed: 3.2ms preprocess, 169.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0003.jpg
#
# 0: 384x640 4 persons, 194.5ms
# Speed: 3.7ms preprocess, 194.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0004.jpg
#
# 0: 384x640 4 persons, 169.6ms
# Speed: 2.3ms preprocess, 169.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0005.jpg
#
# 0: 384x640 4 persons, 170.8ms
# Speed: 3.4ms preprocess, 170.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0006.jpg
#
# 0: 384x640 4 persons, 160.7ms
# Speed: 5.2ms preprocess, 160.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0007.jpg
#
# 0: 384x640 4 persons, 181.7ms
# Speed: 3.0ms preprocess, 181.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0008.jpg
#
# 0: 384x640 4 persons, 170.3ms
# Speed: 2.9ms preprocess, 170.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0009.jpg
#
# 0: 384x640 4 persons, 195.3ms
# Speed: 3.1ms preprocess, 195.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0010.jpg
#
# 0: 384x640 4 persons, 189.7ms
# Speed: 2.6ms preprocess, 189.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0011.jpg
#
# 0: 384x640 4 persons, 160.5ms
# Speed: 3.3ms preprocess, 160.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0012.jpg
#
# 0: 384x640 4 persons, 307.1ms
# Speed: 2.2ms preprocess, 307.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0013.jpg
#
# 0: 384x640 4 persons, 256.4ms
# Speed: 3.4ms preprocess, 256.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0014.jpg
#
# 0: 384x640 3 persons, 287.3ms
# Speed: 2.3ms preprocess, 287.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0015.jpg
#
# 0: 384x640 3 persons, 271.9ms
# Speed: 3.5ms preprocess, 271.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0016.jpg
#
# 0: 384x640 4 persons, 166.5ms
# Speed: 2.3ms preprocess, 166.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0017.jpg
#
# 0: 384x640 4 persons, 174.7ms
# Speed: 3.1ms preprocess, 174.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0018.jpg
#
# 0: 384x640 4 persons, 192.1ms
# Speed: 3.2ms preprocess, 192.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0019.jpg
#
# 0: 384x640 5 persons, 180.1ms
# Speed: 3.3ms preprocess, 180.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0020.jpg
#
# 0: 384x640 4 persons, 186.5ms
# Speed: 4.4ms preprocess, 186.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0021.jpg
#
# 0: 384x640 4 persons, 177.5ms
# Speed: 3.7ms preprocess, 177.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0022.jpg
#
# 0: 384x640 3 persons, 164.9ms
# Speed: 6.4ms preprocess, 164.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0023.jpg
#
# 0: 384x640 3 persons, 166.7ms
# Speed: 4.4ms preprocess, 166.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0024.jpg
#
# 0: 384x640 4 persons, 164.0ms
# Speed: 3.5ms preprocess, 164.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0025.jpg
#
# 0: 384x640 4 persons, 176.6ms
# Speed: 3.1ms preprocess, 176.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0026.jpg
#
# 0: 384x640 4 persons, 168.3ms
# Speed: 3.6ms preprocess, 168.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0027.jpg
#
# 0: 384x640 4 persons, 163.4ms
# Speed: 5.1ms preprocess, 163.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0028.jpg
#
# 0: 384x640 5 persons, 184.4ms
# Speed: 2.2ms preprocess, 184.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0029.jpg
#
# 0: 384x640 3 persons, 167.3ms
# Speed: 2.2ms preprocess, 167.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0030.jpg
#
# 0: 384x640 5 persons, 182.9ms
# Speed: 3.2ms preprocess, 182.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0031.jpg
#
# 0: 384x640 5 persons, 171.4ms
# Speed: 5.7ms preprocess, 171.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0032.jpg
#
# 0: 384x640 5 persons, 180.1ms
# Speed: 2.9ms preprocess, 180.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0033.jpg
#
# 0: 384x640 5 persons, 170.3ms
# Speed: 3.5ms preprocess, 170.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0034.jpg
#
# 0: 384x640 4 persons, 186.5ms
# Speed: 2.7ms preprocess, 186.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0035.jpg
#
# 0: 384x640 4 persons, 173.5ms
# Speed: 2.4ms preprocess, 173.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0036.jpg
#
# 0: 384x640 4 persons, 168.0ms
# Speed: 4.2ms preprocess, 168.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0037.jpg
#
# 0: 384x640 5 persons, 179.6ms
# Speed: 2.2ms preprocess, 179.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0038.jpg
#
# 0: 384x640 7 persons, 256.4ms
# Speed: 2.1ms preprocess, 256.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0039.jpg
#
# 0: 384x640 4 persons, 283.4ms
# Speed: 2.1ms preprocess, 283.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0040.jpg
#
# 0: 384x640 5 persons, 266.7ms
# Speed: 2.2ms preprocess, 266.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0041.jpg
#
# 0: 384x640 6 persons, 306.4ms
# Speed: 2.2ms preprocess, 306.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0042.jpg
#
# 0: 384x640 4 persons, 270.8ms
# Speed: 2.0ms preprocess, 270.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0043.jpg
#
# 0: 384x640 4 persons, 272.5ms
# Speed: 2.2ms preprocess, 272.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0044.jpg
#
# 0: 384x640 5 persons, 287.5ms
# Speed: 2.3ms preprocess, 287.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0045.jpg
#
# 0: 384x640 5 persons, 269.7ms
# Speed: 2.1ms preprocess, 269.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0046.jpg
#
# 0: 384x640 4 persons, 166.2ms
# Speed: 5.1ms preprocess, 166.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0047.jpg
#
# 0: 384x640 5 persons, 178.7ms
# Speed: 3.7ms preprocess, 178.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0048.jpg
#
# 0: 384x640 4 persons, 162.2ms
# Speed: 3.4ms preprocess, 162.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0049.jpg
#
# 0: 384x640 4 persons, 188.4ms
# Speed: 2.7ms preprocess, 188.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0050.jpg
#
# 0: 384x640 4 persons, 169.2ms
# Speed: 3.1ms preprocess, 169.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0051.jpg
#
# 0: 384x640 4 persons, 187.3ms
# Speed: 3.2ms preprocess, 187.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0052.jpg
#
# 0: 384x640 3 persons, 182.6ms
# ...
# Speed: 6.1ms preprocess, 197.3ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0088.jpg
#
# 0: 448x640 1 person, 178.0ms
# Speed: 4.0ms preprocess, 178.0ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0089.jpg
#
# 0: 448x640 1 person, 189.8ms
# Speed: 3.7ms preprocess, 189.8ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0090.jpg
#
# 0: 448x640 1 person, 191.4ms
# Speed: 3.7ms preprocess, 191.4ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0091.jpg
#
# 0: 448x640 1 person, 176.5ms
# Speed: 3.6ms preprocess, 176.5ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0092.jpg
#
# 0: 448x640 1 person, 184.7ms
# Speed: 12.2ms preprocess, 184.7ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0093.jpg
#
# 0: 448x640 1 person, 185.1ms
# Speed: 4.0ms preprocess, 185.1ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0094.jpg
#
# 0: 448x640 1 person, 182.8ms
# Speed: 3.4ms preprocess, 182.8ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0095.jpg
#
# 0: 448x640 1 person, 184.0ms
# Speed: 3.8ms preprocess, 184.0ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0096.jpg
#
# 0: 448x640 1 person, 174.7ms
# Speed: 4.7ms preprocess, 174.7ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0097.jpg
#
# 0: 448x640 1 person, 218.7ms
# Speed: 4.0ms preprocess, 218.7ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0098.jpg
#
# 0: 448x640 1 person, 280.4ms
# Speed: 3.7ms preprocess, 280.4ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0099.jpg
#
# 0: 448x640 1 person, 309.2ms
# Speed: 4.8ms preprocess, 309.2ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0100.jpg
#
# 0: 448x640 1 person, 297.4ms
# Speed: 4.6ms preprocess, 297.4ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0101.jpg
#
# 0: 448x640 1 person, 279.6ms
# Speed: 3.9ms preprocess, 279.6ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0102.jpg
#
# 0: 448x640 1 person, 334.9ms
# Speed: 4.5ms preprocess, 334.9ms inference, 2.9ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0103.jpg
#
# 0: 448x640 1 person, 331.7ms
# Speed: 3.6ms preprocess, 331.7ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0104.jpg
#
# 0: 448x640 1 person, 320.0ms
# Speed: 3.7ms preprocess, 320.0ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0105.jpg
#
# 0: 448x640 2 persons, 354.1ms
# Speed: 3.8ms preprocess, 354.1ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0106.jpg
#
# 0: 448x640 1 person, 282.6ms
# Speed: 3.7ms preprocess, 282.6ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0107.jpg
#
# 0: 448x640 1 person, 282.9ms
# Speed: 3.8ms preprocess, 282.9ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0108.jpg
#
# 0: 448x640 1 person, 285.7ms
# Speed: 3.8ms preprocess, 285.7ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0109.jpg
#
# 0: 448x640 1 person, 285.3ms
# Speed: 8.0ms preprocess, 285.3ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0110.jpg
#
# 0: 448x640 1 person, 302.8ms
# Speed: 3.7ms preprocess, 302.8ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0111.jpg
#
# 0: 448x640 1 person, 175.6ms
# Speed: 4.2ms preprocess, 175.6ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0112.jpg
#
# 0: 448x640 1 person, 182.6ms
# Speed: 4.9ms preprocess, 182.6ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0113.jpg
#
# 0: 448x640 1 person, 179.3ms
# Speed: 5.2ms preprocess, 179.3ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0114.jpg
#
# 0: 448x640 1 person, 187.0ms
# Speed: 4.3ms preprocess, 187.0ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0115.jpg
#
# 0: 448x640 1 person, 172.0ms
# Speed: 4.3ms preprocess, 172.0ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0116.jpg
#
# 0: 448x640 1 person, 187.6ms
# Speed: 3.2ms preprocess, 187.6ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0117.jpg
#
# 0: 448x640 2 persons, 175.0ms
# Speed: 3.5ms preprocess, 175.0ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0118.jpg
#
# 0: 448x640 2 persons, 186.8ms
# Speed: 5.1ms preprocess, 186.8ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0119.jpg
#
# 0: 448x640 2 persons, 184.1ms
# Speed: 4.4ms preprocess, 184.1ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0120.jpg
#
# 0: 448x640 2 persons, 178.3ms
# Speed: 4.4ms preprocess, 178.3ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0121.jpg
#
# 0: 448x640 2 persons, 200.5ms
# Speed: 3.6ms preprocess, 200.5ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0122.jpg
#
# 0: 448x640 2 persons, 180.9ms
# Speed: 5.5ms preprocess, 180.9ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0123.jpg
#
# 0: 448x640 2 persons, 185.1ms
# Speed: 4.9ms preprocess, 185.1ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0124.jpg
#
# 0: 448x640 2 persons, 178.1ms
# Speed: 6.1ms preprocess, 178.1ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0125.jpg
#
# 0: 448x640 2 persons, 195.6ms
# Speed: 4.7ms preprocess, 195.6ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0126.jpg
#
# 0: 448x640 2 persons, 182.0ms
# Speed: 4.4ms preprocess, 182.0ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0127.jpg
#
# 0: 448x640 2 persons, 170.8ms
# Speed: 10.9ms preprocess, 170.8ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0128.jpg
#
# 0: 448x640 2 persons, 192.5ms
# Speed: 3.7ms preprocess, 192.5ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0129.jpg
#
# 0: 448x640 2 persons, 211.2ms
# Speed: 4.7ms preprocess, 211.2ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0130.jpg
#
# 0: 448x640 2 persons, 180.3ms
# Speed: 5.9ms preprocess, 180.3ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0131.jpg
#
# 0: 448x640 2 persons, 184.5ms
# Speed: 8.9ms preprocess, 184.5ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0132.jpg
#
# 0: 448x640 3 persons, 182.8ms
# Speed: 5.0ms preprocess, 182.8ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0133.jpg
#
# 0: 448x640 3 persons, 187.9ms
# Speed: 5.8ms preprocess, 187.9ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0134.jpg
#
# 0: 448x640 3 persons, 295.4ms
# Speed: 5.2ms preprocess, 295.4ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0135.jpg
#
# 0: 448x640 3 persons, 290.9ms
# Speed: 4.8ms preprocess, 290.9ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0136.jpg
#
# 0: 448x640 2 persons, 271.6ms
# Speed: 4.4ms preprocess, 271.6ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0137.jpg
#
# 0: 448x640 2 persons, 288.9ms
# Speed: 3.7ms preprocess, 288.9ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0138.jpg
#
# 0: 448x640 2 persons, 302.7ms
# Speed: 9.3ms preprocess, 302.7ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0139.jpg
#
# 0: 448x640 2 persons, 302.1ms
# Speed: 4.3ms preprocess, 302.1ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0140.jpg
#
# 0: 448x640 2 persons, 246.4ms
# Speed: 5.7ms preprocess, 246.4ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0141.jpg
#
# 0: 448x640 2 persons, 191.0ms
# Speed: 4.6ms preprocess, 191.0ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0142.jpg
#
# 0: 448x640 2 persons, 208.3ms
# Speed: 5.9ms preprocess, 208.3ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0143.jpg
#
# 0: 448x640 2 persons, 176.2ms
# Speed: 6.1ms preprocess, 176.2ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0144.jpg
#
# 0: 448x640 2 persons, 173.0ms
# Speed: 4.9ms preprocess, 173.0ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0145.jpg
#
# 0: 448x640 2 persons, 177.9ms
# Speed: 4.3ms preprocess, 177.9ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0146.jpg
#
# 0: 448x640 2 persons, 174.6ms
# Speed: 5.4ms preprocess, 174.6ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0147.jpg
#
# 0: 448x640 3 persons, 188.7ms
# Speed: 4.5ms preprocess, 188.7ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0148.jpg
#
# 0: 448x640 2 persons, 197.0ms
# Speed: 3.8ms preprocess, 197.0ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0149.jpg
#
# 0: 448x640 2 persons, 191.0ms
# Speed: 4.8ms preprocess, 191.0ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0000.jpg
#
# 0: 448x640 2 persons, 188.6ms
# Speed: 5.2ms preprocess, 188.6ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0001.jpg
#
# 0: 448x640 2 persons, 171.6ms
# Speed: 3.8ms preprocess, 171.6ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0002.jpg
#
# 0: 448x640 2 persons, 178.0ms
# Speed: 3.6ms preprocess, 178.0ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0003.jpg
#
# 0: 448x640 2 persons, 184.6ms
# Speed: 5.0ms preprocess, 184.6ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0004.jpg
#
# 0: 448x640 2 persons, 188.3ms
# Speed: 3.8ms preprocess, 188.3ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0005.jpg
#
# 0: 448x640 2 persons, 181.6ms
# Speed: 4.1ms preprocess, 181.6ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0006.jpg
#
# 0: 448x640 2 persons, 174.3ms
# Speed: 5.0ms preprocess, 174.3ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0007.jpg
#
# 0: 448x640 2 persons, 180.2ms
# Speed: 5.2ms preprocess, 180.2ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0008.jpg
#
# 0: 448x640 2 persons, 189.4ms
# Speed: 6.3ms preprocess, 189.4ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0009.jpg
#
# 0: 448x640 2 persons, 173.2ms
# Speed: 3.8ms preprocess, 173.2ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0010.jpg
#
# 0: 448x640 2 persons, 175.3ms
# Speed: 4.9ms preprocess, 175.3ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0011.jpg
#
# 0: 448x640 2 persons, 187.3ms
# Speed: 5.3ms preprocess, 187.3ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0012.jpg
#
# 0: 448x640 3 persons, 178.7ms
# Speed: 4.5ms preprocess, 178.7ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0013.jpg
#
# 0: 448x640 3 persons, 287.5ms
# Speed: 5.6ms preprocess, 287.5ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0014.jpg
#
# 0: 448x640 3 persons, 286.3ms
# Speed: 3.8ms preprocess, 286.3ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# 결과가 저장되었습니다: /content/drive/MyDrive/zerobase/results/result_frame_0015.jpg
#
# 0: 448x640 2 persons, 280.9ms
# Speed: 6.2ms preprocess, 280.9ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
